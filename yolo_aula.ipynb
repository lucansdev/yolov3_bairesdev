# %% [markdown]
# <a href="https://colab.research.google.com/github/lucansdev/yolov3_bairesdev/blob/main/yolo_aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import cv2
# Out:
# Mounted at /content/gdrive

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !tar -xvf gdrive/My\ Drive/darknet/cudnn-linux-x86_64-9.6.0.74_cuda12-archive.tar.xz -C /usr/local/
# !chmod a+r /usr/local/cuda/include
# Out:
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_adv_static_v9.a
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_cnn_static_v9.a
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_engines_precompiled_static_v9.a
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_engines_runtime_compiled_static_v9.a
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_graph_static_v9.a
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_heuristic_static_v9.a
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_ops_static_v9.a
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_adv_static.a
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_cnn_static.a
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_engines_precompiled_static.a
# cudnn-linux-x86_64-9.6.0.74_cuda12-archive/lib/libcudnn_engines_runtime_compiled_static.a
# ...

# %%
# Leave this code uncommented on the very first run of your notebook or if you ever need to recompile darknet again.
# Comment this code on the future runs.
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet

#Compile Darknet
# !make

#Copies the Darknet compiled version to Google drive
# !cp -r ./ /content/gdrive/My\ Drive/darknet/bin/darknet

# Set execution permissions to Darknet
# !chmod +x ./darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068 (from 1)
# Receiving objects: 100% (10068/10068), 10.14 MiB | 20.44 MiB/s, done.
# Resolving deltas: 100% (6715/6715), done.
# /content/darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:228:21: warning: unused variable ‘n’ [-Wunused-variable]
#   228 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ...

# %%
# Makes a dir for darknet and move there
# !mkdir darknet
# %cd darknet


# Copy the Darkent compiled version to the VM local drive
# !cp -r /content/gdrive/My\ Drive/darknet/bin/darknet ./


# Set execution permissions to Darknet
# !chmod +x ./darknet
# Out:
# mkdir: cannot create directory ‘darknet’: File exists
# [Errno 20] Not a directory: 'darknet'
# /content/darknet
# cp: cannot stat '/content/gdrive/My Drive/darknet/bin/darknet': No such file or directory

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2025-01-06 16:31:45--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  12.0MB/s    in 11s
#
# 2025-01-06 16:31:56 (22.2 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !./darknet detector test ./cfg/coco.data ./cfg/yolov3.cfg ./yolov3.weights
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
# !./darknet detector train ./cfg/coco.data ./cfg/yolov3.cfg ./darknet53.conv.74
# Out:
# yolov3
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...
